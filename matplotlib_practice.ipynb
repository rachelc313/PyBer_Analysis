# %%
# Ensure plots are displayed within the Jupyter Notebok directly below the code cell that produced, using a magic command.
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Pie graphs using object-oriented interface Skill Drill -

# Identify colors 
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

# Identify explode values
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis, explode=explode_values, colors=colors, labels=x_axis, autopct='%.1f%%', shadow=True, startangle=-90)
plt.gca().invert_yaxis()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# #pie graphs
# plt.pie(y_axis, labels=x_axis)
# plt.show()

# %%
# # Assign 12 colors, one for each month
# colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
# explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
# plt.subplots(figsize=(8, 8))
# plt.pie(y_axis, explode=explode_values, colors=colors, labels=x_axis, autopct='%.1f%%')

# plt.show()

# %%
# Create a scatter plot using the object-oriented interface

# #Create plot
# fig, ax = plt.subplots()
# ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# The format for list comprehension:
# new_list = [expression for item in list if conditional]
# much more efficient

# # Use list comprehension to make the markers larger 
# plt.scatter(y_axis, x_axis, edgecolors="black", c="skyblue", alpha=0.2, s = [i * 5 for i in y_axis], linewidth=2, label='Boston')

# #add legend
# plt.legend()

# # Add labels to x and y axes
# plt.xlabel("Fare($)")
# plt.ylabel("Date")

# # Add title
# plt.title("PyBer Fare by Month")

# # Add a  limit to the x-axis data
# plt.xlim(0, 50)

# # Invert y-axis so Jan is on top
# plt.gca().invert_yaxis()

# #Set plot and markers
# plt.scatter(x_axis, y_axis, s=y_axis)

#iterate through y_axis and multiply by 3 to increase size of markers

# # set variable
# y_axis_larger = []

# #run for loop
# for data in y_axis:
#     y_axis_larger.append(data*3)

# #Display eith new size
# plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# # Set plot to scatter plot using plt.plot() method - 
# plt.plot(x_axis, y_axis, 'o')

# %%
# # Set plot to scatter using the plt.scatter() method, set color to red add a label, put fare on x axis and dates on y axis
# plt.scatter(y_axis, x_axis, c="red", label='Chicago')

# # Add labels to x and y axes
# plt.xlabel('Fare($)')
# plt.ylabel('Date')

# # Add a legend
# plt.legend()

# # Add a limit to the x axis
# plt.xlim(0, 50)

# #invert y-axis so January is at top
# plt.gca().invert_yaxis()

# %%
# #Using object-oriented approach

# # Create the plot with ax.plt()
# fig, ax = plt.subplots()

# #set the x and y axes and a label
# ax.barh(x_axis, y_axis, color="cyan", label='Chicago')

# # Set the labels for the x and y axes
# ax.set_xlabel('Fare($)')
# ax.set_ylabel('Date')

# # Add a legend
# ax.legend()

# # Invert y axis to show months in correct order
# ax.invert_yaxis()


# # Create the plot with ax.plt()
# fig, ax = plt.subplots()
# ax.bar(x_axis, y_axis, color="black", label='New York')

# %%
# # Create the plot, change the color to magenta and add label "Boston"
# plt.barh(x_axis, y_axis, color="magenta", label='Boston')

# #Create labels for the x and y axes
# plt.xlabel("Fare($)")
# plt.ylabel("Date")

# #Create a legend
# plt.legend()

# #Create a title
# plt.title("PyBer Fare by Month")

# # Invert y axis to put months in correct order
# plt.gca().invert_yaxis()

# %%
# # Create the plot, set color and label
# plt.bar(x_axis, y_axis, color="green", label='Boston')

# #Create labels for the x and y axes
# plt.xlabel("Date")
# plt.ylabel("Fare($)")

# # Create a title
# plt.title("PyBar Fare by Month")

# #Add the legend
# plt.legend()

# %%
# # Create the plot and add a label for the legend. Set the color, width, and marker to diamond
# plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')

# #Create labels for the x and y axes.
# plt.xlabel("Date")
# plt.ylabel("Fare($)")

# # Set the y limit between 0 and 45
# plt.ylim(0, 45)


# # Create a title
# plt.title("PyBer Fare by Month")

# # Add a grid
# plt.grid()

# # Add a legend
# plt.legend()
